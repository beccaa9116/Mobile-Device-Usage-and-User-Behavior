# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

data = pd.read_csv('user_behavior_dataset.csv')
data.head(5)
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User ID                     700 non-null    int64
#  1   Device Model                700 non-null    object
#  2   Operating System            700 non-null    object
#  3   App Usage Time (min/day)    700 non-null    int64
#  4   Screen On Time (hours/day)  700 non-null    float64
#  5   Battery Drain (mAh/day)     700 non-null    int64
#  6   Number of Apps Installed    700 non-null    int64
#  7   Data Usage (MB/day)         700 non-null    int64
#  8   Age                         700 non-null    int64
#  9   Gender                      700 non-null    object
#  10  User Behavior Class         700 non-null    int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 60.3+ KB

# %%
data.dropna()
data.isnull().sum()
# Out:
# User ID                       0
# Device Model                  0
# Operating System              0
# App Usage Time (min/day)      0
# Screen On Time (hours/day)    0
# Battery Drain (mAh/day)       0
# Number of Apps Installed      0
# Data Usage (MB/day)           0
# Age                           0
# Gender                        0
# User Behavior Class           0
# dtype: int64

# %%
data.describe()
# Out:
#          User ID  App Usage Time (min/day)  Screen On Time (hours/day)  \
# count  700.00000                700.000000                  700.000000
# mean   350.50000                271.128571                    5.272714
# std    202.21688                177.199484                    3.068584
# min      1.00000                 30.000000                    1.000000
# 25%    175.75000                113.250000                    2.500000
# 50%    350.50000                227.500000                    4.900000
# 75%    525.25000                434.250000                    7.400000
# max    700.00000                598.000000                   12.000000
#
#        Battery Drain (mAh/day)  Number of Apps Installed  Data Usage (MB/day)  \
# count               700.000000                700.000000           700.000000
# mean               1525.158571                 50.681429           929.742857
# std                 819.136414                 26.943324           640.451729
# ...

# %%
data.shape
# Out:
# (700, 11)

# %%
data.nunique()
# Out:
# User ID                       700
# Device Model                    5
# Operating System                2
# App Usage Time (min/day)      387
# Screen On Time (hours/day)    108
# Battery Drain (mAh/day)       628
# Number of Apps Installed       86
# Data Usage (MB/day)           585
# Age                            42
# Gender                          2
# User Behavior Class             5
# dtype: int64

# %%
#plot device model
plt.figure(figsize=(10, 6))
plt.hist(data['Device Model'], bins=5, color='skyblue', edgecolor='black')
plt.title('Device Model Distribution')
plt.xlabel('Device Model')
plt.ylabel('Frequency')
plt.show()

# %%
#plot operating system
plt.figure(figsize=(10, 6))
plt.hist(data['Operating System'], bins=2, color='lightgreen', edgecolor='black')
plt.title('Operating System Distribution')
plt.xlabel('Operating System')
plt.ylabel('Frequency')
plt.show()

# %%
#plot app usage time in histplot
plt.figure(figsize=(10, 5))
sns.histplot(data['App Usage Time (min/day)'], bins=50, kde=True)
plt.title('Distribution of App Usage Time')
plt.xlabel('App Usage Time')
plt.ylabel('Frequency')
plt.show()
# Out:
# /Users/rebekaborsikova/opt/anaconda3/envs/mypython3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#plot screen on time 
plt.figure(figsize=(10, 5))
sns.histplot(data['Screen On Time (hours/day)'], bins=50, color='red', kde=True)
plt.title('Distribution of Screen On Time')
plt.xlabel('Screen On Time')
plt.ylabel('Frequency')
plt.show()
# Out:
# /Users/rebekaborsikova/opt/anaconda3/envs/mypython3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#distribution of Battery Drain (mAh/day) 
plt.figure(figsize=(10, 5))
sns.histplot(data['Battery Drain (mAh/day)'], bins=50, color='lightgreen', kde=True)
plt.title('Distribution of Battery Drain')
plt.xlabel('Battery Drain')
plt.ylabel('Frequency')
plt.show()
# Out:
# /Users/rebekaborsikova/opt/anaconda3/envs/mypython3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#distribution of Number of Apps Installed 
plt.figure(figsize=(10, 5))
sns.histplot(data['Number of Apps Installed'], bins=50, color='orange', kde=True)
plt.title('Distribution of Number of Apps Installed')
plt.xlabel('Number of Apps Installed')
plt.ylabel('Frequency')
plt.show()
# Out:
# /Users/rebekaborsikova/opt/anaconda3/envs/mypython3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#distribution of Data Usage (MB/day) 
plt.figure(figsize=(10, 5))
sns.histplot(data['Data Usage (MB/day)'], bins=50, color='purple', kde=True)
plt.title('Distribution of Data Usage')
plt.xlabel('Data Usage')
plt.ylabel('Frequency')
plt.show()
# Out:
# /Users/rebekaborsikova/opt/anaconda3/envs/mypython3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#distribution of age
plt.figure(figsize=(10, 5))
sns.histplot(data['Age'], bins=10, color='pink', kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# /Users/rebekaborsikova/opt/anaconda3/envs/mypython3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#distribution of gender
plt.figure(figsize=(10, 5))
sns.histplot(data['Gender'], color='violet', bins=2)
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.show()
# Out:
# /Users/rebekaborsikova/opt/anaconda3/envs/mypython3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#distribution of User Behavior Class  
plt.figure(figsize=(10, 5))
sns.histplot(data['User Behavior Class'], bins=5)
plt.title('Distribution of User Behavior Class')
plt.xlabel('User Behavior Class')
plt.ylabel('Frequency')
plt.show()
# Out:
# /Users/rebekaborsikova/opt/anaconda3/envs/mypython3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#compare app usage and number of apps installed
plt.figure(figsize=(10, 5))
sns.scatterplot(x='App Usage Time (min/day)', y='Number of Apps Installed', hue='User Behavior Class', palette='viridis', data=data)
plt.title('Comparison of App Usage Time and Number of Apps Installed')
plt.xlabel('App Usage Time (min/day)')
plt.ylabel('Number of Apps Installed')
plt.show()

# %%
#compare screen on time and app usage time
plt.figure(figsize=(10, 5))
sns.scatterplot(x='Screen On Time (hours/day)', y='App Usage Time (min/day)', hue='User Behavior Class', data=data)
plt.title('Comparison of Screen On Time and App Usage Time')
plt.xlabel('Screen On Time (hours/day)')
plt.ylabel('App Usage Time (min/day)')
plt.show()

# %%
#compare screen on time and battery drain
plt.figure(figsize=(10, 5))
sns.scatterplot(x='Screen On Time (hours/day)', y='Battery Drain (mAh/day)', hue='User Behavior Class', palette='crest', data=data)
plt.title('Comparison of Screen On Time and Battery Drain')
plt.xlabel('Screen On Time (hours/day)')
plt.ylabel('Battery Drain (mAh/day)')
plt.show()

# %%
#compare screen on time and number of apps installed
plt.figure(figsize=(10, 5))
sns.scatterplot(x='Screen On Time (hours/day)', y='Number of Apps Installed', hue='User Behavior Class', palette='mako', data=data)
plt.title('Comparison of Screen On Time and Number of Apps Installed')
plt.xlabel('Screen On Time (hours/day)')
plt.ylabel('Number of Apps Installed')
plt.show()

# %%
data.head(1)
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
#
#    Number of Apps Installed  Data Usage (MB/day)  Age Gender  \
# 0                        67                 1122   40   Male
#
#    User Behavior Class
# 0                    4

# %%
#compare screen on time and data usage
plt.figure(figsize=(10, 5))
sns.scatterplot(x='Screen On Time (hours/day)', y='Data Usage (MB/day)', hue='User Behavior Class', palette='icefire', data=data)
plt.title('Comparison of Screen On Time and Data Usage')
plt.xlabel('Screen On Time (hours/day)')
plt.ylabel('Data Usage (MB/day)')
plt.show()

# %%
#compare age and screen on time
plt.figure(figsize=(10, 5))
sns.scatterplot(x='Age', y='Screen On Time (hours/day)', hue='Operating System', palette='rocket', data=data)
plt.title('Comparison of Age and Screen On Time')
plt.xlabel('Age')
plt.ylabel('Screen On Time (hours/day)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='User Behavior Class')
plt.show()

# %%
#compare age and app usage time
plt.figure(figsize=(10, 5))
sns.scatterplot(x='Age', y='App Usage Time (min/day)', hue='User Behavior Class', data=data)
plt.title('Comparison of Age and App Usage Time')
plt.xlabel('Age')
plt.ylabel('App Usage Time (min/day)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='User Behavior Class')
plt.show()

# %%
#compare age and data usage
plt.figure(figsize=(10, 5))
sns.scatterplot(x='Age', y='Data Usage (MB/day)', hue='Gender', palette='viridis', data=data)
plt.title('Comparison of Age and Data Usage')
plt.xlabel('Age')
plt.ylabel('Data Usage (MB/day)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='User Behavior Class')
plt.show()

# %%
#compare gender to different factors
data.head(1)
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
#
#    Number of Apps Installed  Data Usage (MB/day)  Age Gender  \
# 0                        67                 1122   40   Male
#
#    User Behavior Class
# 0                    4

# %%
#top device models
plt.figure(figsize=(10, 5))
sns.countplot(y='Device Model', data=data, order=data['Device Model'].value_counts().index, palette='viridis')
plt.title('Top Device Models')
plt.xlabel('Count')
plt.ylabel('Device Model')
plt.show()

# %%
#highest app usage time
data_sorted = data.sort_values(by='App Usage Time (min/day)', ascending=False)
top_10_highest = data_sorted.head(10)
top_10_highest['App Usage Time (min/day)']
# Out:
# 367    598
# 341    597
# 184    597
# 166    595
# 654    594
# 537    593
# 34     593
# 539    592
# 451    591
# 49     589
# Name: App Usage Time (min/day), dtype: int64

# %%
#which operating system has the oldest users
plt.figure(figsize=(10, 5))
sns.boxplot(x='Operating System', y='Age', data=data, palette='magma')
plt.title('Comparison of Operating System and Age')
plt.xlabel('Operating System')
plt.ylabel('Age')
plt.show()
